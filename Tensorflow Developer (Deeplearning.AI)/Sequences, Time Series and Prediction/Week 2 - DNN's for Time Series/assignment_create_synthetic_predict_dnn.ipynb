# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %%
def plot_series(time, series, format="-", start=0, end=None):
    plt.plot(time[start:end], series[start:end], format)
    plt.xlabel("Time")
    plt.ylabel("Value")
    plt.grid(False)

def trend(time, slope=0):
    return slope * time

def seasonal_pattern(season_time):
    """Just an arbitrary pattern, you can change it if you wish"""
    return np.where(season_time < 0.1,
                    np.cos(season_time * 6 * np.pi), # YOUR CODE HERE # * np.pi),
                    2 / np.exp(9 * season_time)) #YOUR CODE HERE# / np.exp(#YOUR CODE HERE# * season_time))

def seasonality(time, period, amplitude=1, phase=0):
    """Repeats the same pattern at each period"""
    season_time = ((time + phase) % period) / period
    return amplitude * seasonal_pattern(season_time)

def noise(time, noise_level=1, seed=None):
    rnd = np.random.RandomState(seed)
    return rnd.randn(len(time)) * noise_level

time = np.arange(10 * 365 + 1, dtype="float32")
baseline = 10 # YOUR CODE HERE #
series = trend(time, 0.1)# YOUR CODE HERE#)
baseline = 10
amplitude = 40
slope = 0.005 # YOUR CODE HERE#
noise_level = 3 # YOUR CODE HERE#

# Create the series
series = baseline + trend(time, slope) + seasonality(time, period=365, amplitude=amplitude)
# Update with noise
series += noise(time, noise_level, seed=51)

split_time = 3000
time_train = time[:split_time]
x_train = series[:split_time]
time_valid = time[split_time:]
x_valid = series[split_time:]

window_size = 20
batch_size = 32
shuffle_buffer_size = 1000

# # # # # expected output
# !gdown --id 1sDzcLKVZBQWeEYT101bEWCltlaFPjiIN
print("Expected:")
from IPython.display import display
from PIL import Image
path='./C4_W2_Assignment_Image.png'
display(Image.open(path))
# # # # #

### your output
print("Your output:")
plot_series(time, series)
# Out:
# Expected:
# Downloading...
# From: https://drive.google.com/uc?id=1sDzcLKVZBQWeEYT101bEWCltlaFPjiIN
# To: C:\Users\benja\Documents\Development\Python\Tensorflow Developer\Sequences, Time Series and Prediction\Week 2 - DNN's for Time Series\C4_W2_Assignment_Image.png
#
#   0%|          | 0.00/18.5k [00:00<?, ?B/s]
# 100%|##########| 18.5k/18.5k [00:00<00:00, 1.18MB/s]
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=391x262 at 0x1882A9DF6D0>
# Your output:

# %%
def windowed_dataset(series, window_size, batch_size, shuffle_buffer):
    dataset = tf.data.Dataset.from_tensor_slices(series)
    dataset = dataset.window(window_size + 1, shift=1, drop_remainder=True)
    dataset = dataset.flat_map(lambda window: window.batch(window_size + 1))
    dataset = dataset.shuffle(shuffle_buffer).map(lambda window: (window[:-1], window[-1]))
    dataset = dataset.batch(batch_size).prefetch(1)
    return dataset

# %%
dataset = windowed_dataset(x_train, window_size, batch_size, shuffle_buffer_size)


model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(100, input_shape=[window_size], activation="relu"), # YOUR CODE HERE #),
    tf.keras.layers.Dense(10, activation="relu"), # YOUR CODE HERE #, activation="relu"),
    tf.keras.layers.Dense(1)
])

model.compile(loss="mse", optimizer=tf.keras.optimizers.SGD(learning_rate=1e-6, momentum=0.9))# YOUR CODE HERE #, optimizer=# YOUR CODE HERE#))
model.fit(dataset,epochs=100)
# Out:
# Epoch 1/100
# 94/94 [==============================] - 1s 2ms/step - loss: 65.0510
# Epoch 2/100
# 94/94 [==============================] - 0s 2ms/step - loss: 30.6603
# Epoch 3/100
# 94/94 [==============================] - 0s 2ms/step - loss: 27.9359
# Epoch 4/100
# 94/94 [==============================] - 0s 2ms/step - loss: 26.7665
# Epoch 5/100
# 94/94 [==============================] - 0s 3ms/step - loss: 26.0213
# Epoch 6/100
# 94/94 [==============================] - 0s 3ms/step - loss: 25.5963
# Epoch 7/100
# 94/94 [==============================] - 0s 2ms/step - loss: 25.1820
# Epoch 8/100
# 94/94 [==============================] - 0s 3ms/step - loss: 24.8934
# Epoch 9/100
# 94/94 [==============================] - 0s 2ms/step - loss: 24.7553
# Epoch 10/100
# 94/94 [==============================] - 0s 3ms/step - loss: 24.6096
# Epoch 11/100
# 94/94 [==============================] - 0s 2ms/step - loss: 24.3102
# Epoch 12/100
# 94/94 [==============================] - 0s 3ms/step - loss: 24.3281
# Epoch 13/100
# 94/94 [==============================] - 0s 2ms/step - loss: 24.0965
# Epoch 14/100
# 94/94 [==============================] - 0s 2ms/step - loss: 23.9453
# Epoch 15/100
# 94/94 [==============================] - 0s 3ms/step - loss: 23.8877
# Epoch 16/100
# 94/94 [==============================] - 0s 3ms/step - loss: 23.6924
# Epoch 17/100
# 94/94 [==============================] - 0s 2ms/step - loss: 23.5613
# Epoch 18/100
# 94/94 [==============================] - 0s 2ms/step - loss: 23.4844
# Epoch 19/100
# 94/94 [==============================] - 0s 3ms/step - loss: 23.4368
# Epoch 20/100
# 94/94 [==============================] - 0s 3ms/step - loss: 23.4305
# Epoch 21/100
# 94/94 [==============================] - 0s 2ms/step - loss: 23.4166
# Epoch 22/100
# 94/94 [==============================] - 0s 2ms/step - loss: 23.1038
# Epoch 23/100
# 94/94 [==============================] - 0s 3ms/step - loss: 23.0261
# Epoch 24/100
# 94/94 [==============================] - 0s 3ms/step - loss: 22.9905
# Epoch 25/100
# 94/94 [==============================] - 0s 2ms/step - loss: 22.9389
# Epoch 26/100
# 94/94 [==============================] - 0s 3ms/step - loss: 22.8876
# Epoch 27/100
# 94/94 [==============================] - 0s 2ms/step - loss: 22.8007
# Epoch 28/100
# 94/94 [==============================] - 0s 3ms/step - loss: 22.7390
# Epoch 29/100
# 94/94 [==============================] - 0s 3ms/step - loss: 22.7739
# Epoch 30/100
# 94/94 [==============================] - 0s 3ms/step - loss: 22.9657
# Epoch 31/100
# 94/94 [==============================] - 0s 2ms/step - loss: 22.5921
# Epoch 32/100
# 94/94 [==============================] - 0s 2ms/step - loss: 22.6648
# Epoch 33/100
# 94/94 [==============================] - 0s 3ms/step - loss: 22.4520
# Epoch 34/100
# 94/94 [==============================] - 0s 2ms/step - loss: 22.6246
# Epoch 35/100
# 94/94 [==============================] - 0s 2ms/step - loss: 22.3667
# Epoch 36/100
# 94/94 [==============================] - 0s 2ms/step - loss: 22.3895
# Epoch 37/100
# 94/94 [==============================] - 0s 3ms/step - loss: 22.2772
# Epoch 38/100
# 94/94 [==============================] - 0s 3ms/step - loss: 22.4125
# Epoch 39/100
# 94/94 [==============================] - 0s 2ms/step - loss: 22.2717
# Epoch 40/100
# 94/94 [==============================] - 0s 3ms/step - loss: 22.2067
# Epoch 41/100
# 94/94 [==============================] - 0s 2ms/step - loss: 22.1768
# Epoch 42/100
# 94/94 [==============================] - 0s 3ms/step - loss: 22.2124
# Epoch 43/100
# 94/94 [==============================] - 0s 3ms/step - loss: 22.0812
# Epoch 44/100
# 94/94 [==============================] - 0s 2ms/step - loss: 22.1018
# Epoch 45/100
# 94/94 [==============================] - 0s 3ms/step - loss: 22.0443
# Epoch 46/100
# 94/94 [==============================] - 0s 3ms/step - loss: 22.0362
# Epoch 47/100
# 94/94 [==============================] - 0s 2ms/step - loss: 22.0141
# Epoch 48/100
# 94/94 [==============================] - 0s 3ms/step - loss: 21.9522
# Epoch 49/100
# 94/94 [==============================] - 0s 3ms/step - loss: 22.1309
# Epoch 50/100
# 94/94 [==============================] - 0s 3ms/step - loss: 22.1125
# Epoch 51/100
# 94/94 [==============================] - 0s 2ms/step - loss: 22.0901
# Epoch 52/100
# 94/94 [==============================] - 0s 3ms/step - loss: 21.8935
# Epoch 53/100
# 94/94 [==============================] - 0s 3ms/step - loss: 21.7897
# Epoch 54/100
# 94/94 [==============================] - 0s 2ms/step - loss: 21.8718
# Epoch 55/100
# 94/94 [==============================] - 0s 3ms/step - loss: 21.7809
# Epoch 56/100
# 94/94 [==============================] - 0s 3ms/step - loss: 21.7451
# Epoch 57/100
# 94/94 [==============================] - 0s 2ms/step - loss: 21.7725
# Epoch 58/100
# 94/94 [==============================] - 0s 3ms/step - loss: 21.7606
# Epoch 59/100
# 94/94 [==============================] - 0s 3ms/step - loss: 21.6266
# Epoch 60/100
# 94/94 [==============================] - 0s 3ms/step - loss: 21.7991
# Epoch 61/100
# 94/94 [==============================] - 0s 3ms/step - loss: 21.6654
# Epoch 62/100
# 94/94 [==============================] - 0s 2ms/step - loss: 21.7219
# Epoch 63/100
# 94/94 [==============================] - 0s 3ms/step - loss: 21.8260
# Epoch 64/100
# 94/94 [==============================] - 0s 3ms/step - loss: 21.6388
# Epoch 65/100
# 94/94 [==============================] - 0s 2ms/step - loss: 21.5323
# Epoch 66/100
# 94/94 [==============================] - 0s 2ms/step - loss: 21.6443
# Epoch 67/100
# 94/94 [==============================] - 0s 2ms/step - loss: 21.4452
# Epoch 68/100
# 94/94 [==============================] - 0s 3ms/step - loss: 21.5150
# Epoch 69/100
# 94/94 [==============================] - 0s 3ms/step - loss: 21.4278
# Epoch 70/100
# 94/94 [==============================] - 0s 3ms/step - loss: 21.5183
# Epoch 71/100
# 94/94 [==============================] - 0s 3ms/step - loss: 21.5566
# Epoch 72/100
# 94/94 [==============================] - 0s 3ms/step - loss: 21.4022
# Epoch 73/100
# 94/94 [==============================] - 0s 3ms/step - loss: 21.4404
# Epoch 74/100
# 94/94 [==============================] - 0s 3ms/step - loss: 21.3067
# Epoch 75/100
# 94/94 [==============================] - 0s 3ms/step - loss: 21.2976
# Epoch 76/100
# 94/94 [==============================] - 0s 2ms/step - loss: 21.5615
# Epoch 77/100
# 94/94 [==============================] - 0s 3ms/step - loss: 21.4458
# Epoch 78/100
# 94/94 [==============================] - 0s 3ms/step - loss: 21.3063
# Epoch 79/100
# 94/94 [==============================] - 0s 2ms/step - loss: 21.2640
# Epoch 80/100
# 94/94 [==============================] - 0s 3ms/step - loss: 21.1844
# Epoch 81/100
# 94/94 [==============================] - 0s 3ms/step - loss: 21.2317
# Epoch 82/100
# 94/94 [==============================] - 0s 2ms/step - loss: 21.0804
# Epoch 83/100
# 94/94 [==============================] - 0s 3ms/step - loss: 21.2003
# Epoch 84/100
# 94/94 [==============================] - 0s 2ms/step - loss: 21.1507
# Epoch 85/100
# 94/94 [==============================] - 0s 3ms/step - loss: 21.0944
# Epoch 86/100
# 94/94 [==============================] - 0s 2ms/step - loss: 21.0956
# Epoch 87/100
# 94/94 [==============================] - 0s 3ms/step - loss: 21.2725
# Epoch 88/100
# 94/94 [==============================] - 0s 2ms/step - loss: 21.0276
# Epoch 89/100
# 94/94 [==============================] - 0s 3ms/step - loss: 21.0233
# Epoch 90/100
# 94/94 [==============================] - 0s 3ms/step - loss: 21.0195
# Epoch 91/100
# 94/94 [==============================] - 0s 3ms/step - loss: 20.9560
# Epoch 92/100
# 94/94 [==============================] - 0s 3ms/step - loss: 21.0111
# Epoch 93/100
# 94/94 [==============================] - 0s 3ms/step - loss: 20.9507
# Epoch 94/100
# 94/94 [==============================] - 0s 3ms/step - loss: 20.9889
# Epoch 95/100
# 94/94 [==============================] - 0s 3ms/step - loss: 20.8280
# Epoch 96/100
# 94/94 [==============================] - 0s 2ms/step - loss: 20.8681
# Epoch 97/100
# 94/94 [==============================] - 0s 3ms/step - loss: 20.8694
# Epoch 98/100
# 94/94 [==============================] - 0s 2ms/step - loss: 20.8575
# Epoch 99/100
# 94/94 [==============================] - 0s 2ms/step - loss: 20.8301
# Epoch 100/100
# 94/94 [==============================] - 0s 3ms/step - loss: 20.7273

# %%
forecast = []
for time in range(len(series) - window_size):
    forecast.append(model.predict(series[time:time + window_size][np.newaxis]))

forecast = forecast[split_time-window_size:]
results = np.array(forecast)[:, 0, 0]


plt.figure(figsize=(10, 6))

plot_series(time_valid, x_valid)
plot_series(time_valid, results)

# %%
tf.keras.metrics.mean_absolute_error(x_valid, results).numpy()
# Out:
# 2.9859264
